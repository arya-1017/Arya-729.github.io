# %% [markdown]
# <a href="https://colab.research.google.com/github/arya-1017/Arya-729.github.io/blob/master/w3-brain-structure/w3-exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neuro4ML - Week 3 - Brain structure
#
# This week we're going to analyse some real data, which come from larval zebrafish.
#
# Larval zebrafish are an increasingly used model in neuroscience for three main reasons:
# 1. They develop rapidly ex utero, from a single cell to a free-swimming larva in just four days, meaning that their development can be easily studied.
# 2. They display a variety of behaviours including a distinct locomotor repertoire, a diurnal pattern of activity and by three weeks of age, social preference.
# 3. They have a vertebrate brain plan and at larval stages are small (~4mm body length) and translucent, enabling cellular-resolution whole-brain imaging in both fixed tissue and live animals.
#
# In this notebook we're going to look at the 3d morphology of ~4,000 neurons in the zebrafish brain. In brief these morphologies were obtained by:
# * Fluorescently labeling 1-2 neurons per animal.
# * Imaging each animal and tracing each neuron.
# * Aligning these images in 3d so that all neurons are in a common reference frame.
#
# You can learn more about the data in [Kunst et al., 2019](https://doi.org/10.1016/j.neuron.2019.04.034) or on this [website](https://mapzebrain.org/home).
#
# There are four parts to the exercise: loading the data, looking at the data, estimating a connectivity matrix and some open exploration.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# !pip install neurom
import neurom as nm
from neurom.view.matplotlib_impl import plot_morph

def figure():
    fig, ax = plt.subplots(figsize=[6, 8], sharex=True, sharey=True)
    ax.set_aspect('equal')
    ax.axis("off")
    plt.gca().invert_yaxis()

    return fig, ax
# Out:
# Collecting neurom
#   Downloading neurom-4.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from neurom) (8.3.0)
# Requirement already satisfied: matplotlib>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from neurom) (3.10.0)
# Collecting morphio>=3.3.6 (from neurom)
#   Downloading morphio-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from neurom) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from neurom) (2.2.2)
# Requirement already satisfied: pyyaml>=3.10 in /usr/local/lib/python3.12/dist-packages (from neurom) (6.0.3)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from neurom) (1.16.2)
# Requirement already satisfied: tqdm>=4.8.4 in /usr/local/lib/python3.12/dist-packages (from neurom) (4.67.1)
# Collecting cached-property>=1.5.1 (from neurom)
#   Downloading cached_property-2.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->neurom) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->neurom) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->neurom) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->neurom) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->neurom) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->neurom) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->neurom) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.1->neurom) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->neurom) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->neurom) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.1->neurom) (1.17.0)
# Downloading neurom-4.0.4-py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.1/110.1 kB 3.5 MB/s eta 0:00:00
# Downloading cached_property-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading morphio-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 35.9 MB/s eta 0:00:00
# Installing collected packages: morphio, cached-property, neurom
# Successfully installed cached-property-2.0.1 morphio-3.4.0 neurom-4.0.4

# %% [markdown]
# ### Part 0 - Loading the data
#
# Before getting started we need to download the data.
#
# How to do this depends on how you're working:
# * **Locally**: download the data [here](https://api.mapzebrain.org/media/downloads/Neurons/mapZebrain__neurons.zip), unzip the folder and provide a path to the Aligned/Original folder in the cell below - something like './mapZebrain__neurons/Aligned/Original'.
# * **Colab**: run the three commands in the cell below to fetch, unzip and provide a path to the data.

# %%
# Download the data

# Locally:
# folder_path = ""  # provide a path to the Aligned/Original folder

# Colab:
# !wget https://api.mapzebrain.org/media/downloads/Neurons/mapZebrain__neurons.zip
# !unzip /content/mapZebrain__neurons.zip
folder_path = "/content/Aligned/Original"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: Aligned/Original/T_170704_3_1.swc
#   inflating: Aligned/Original/T_161019_3_1.swc
#   inflating: Aligned/Original/T_191007_9_1.swc
#   inflating: Aligned/Original/T_200214_5_GFP_1.swc
#   inflating: Aligned/Original/T_160809_4_6.swc
#   inflating: Aligned/Original/T_190312_8_1.swc
#   inflating: Aligned/Original/T_160721_HuCxBG_12_2.swc
#   inflating: Aligned/Original/T_170201_4_2.swc
#   inflating: Aligned/Original/T_160920_18_2.swc
#   inflating: Aligned/Original/T_181102_13_2_Eva.swc
#   inflating: Aligned/Original/T_200909_15_GFP_1.swc
#   inflating: Aligned/Original/T_unres_2016-04-05_fish1_cellB_left_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/T_190531_12_2.swc
#   inflating: Aligned/Original/FT_T_mdG_L6.swc
#   inflating: Aligned/Original/T_230111_5_2.swc
#   inflating: Aligned/Original/20161125_1013_BGUG_HuC_ltRFP_d7_F5.swc
#   inflating: Aligned/Original/T_150609_354_fixed_16_1_full_tracing.swc
#   inflating: Aligned/Original/T_145_2015-11-13_fish1_right_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/20161006_1013_BGUG_HuC_ltRFP_d6_F2.swc
#   inflating: Aligned/Original/20161123_1013_BGUG_HuC_ltRFP_d5_F7.swc
#   inflating: Aligned/Original/T_160705_17_1.swc
#   inflating: Aligned/Original/T_161010_7_1.swc
#   inflating: Aligned/Original/T_190131_14_2.swc
#   inflating: Aligned/Original/T_190125_4_1.swc
#   inflating: Aligned/Original/T_191007_15_4_M.swc
#   inflating: Aligned/Original/T_190121_1_1.swc
#   inflating: Aligned/Original/T_161121_HuCxBG_12_2.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_8_1.swc
#   inflating: Aligned/Original/T_145_2016-06-27_fish2_cellA_left_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_23_2.swc
#   inflating: Aligned/Original/T_201208_5_GFP_1.swc
#   inflating: Aligned/Original/T_170714_7_3.swc
#   inflating: Aligned/Original/33_mod_T_160804_F2M4_loom+dimm+df_FRUEH_02.swc
#   inflating: Aligned/Original/T_190115_5_1.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_25_1.swc
#   inflating: Aligned/Original/T_160502_16_2.swc
#   inflating: Aligned/Original/20170617_1013_BGUG_HuC_ltRFP_d7_F3_Neuron2.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_3_1.swc
#   inflating: Aligned/Original/20170608_1013_BGUG_HuC_ltRFP_d6_F1.swc
#   inflating: Aligned/Original/T_190405_10_1.swc
#   inflating: Aligned/Original/20170303_1013_BGUG_HuC_ltRFP_d7_F2_Neuron1.swc
#   inflating: Aligned/Original/20170329_1013_BGUG_HuC_ltRFP_d6_F2.swc
#   inflating: Aligned/Original/T_200107_3_1.swc
#   inflating: Aligned/Original/T_161108_2_1.swc
#   inflating: Aligned/Original/20170313_1013_BGUG_HuC_ltRFP_d5_F8.swc
#   inflating: Aligned/Original/T_200907_5_2.swc
#   inflating: Aligned/Original/T_161121_0_GFP_5.swc
#   inflating: Aligned/Original/T_190206_25_1.swc
#   inflating: Aligned/Original/T_190531_12_8_M.swc
#   inflating: Aligned/Original/T_150324_fixed_14_2_full_tracing.swc
#   inflating: Aligned/Original/T_200124_1_2.swc
#   inflating: Aligned/Original/T_200325_8_1.swc
#   inflating: Aligned/Original/T_230816_2_4.swc
#   inflating: Aligned/Original/T_201009_26_GFP_2.swc
#   inflating: Aligned/Original/T_151208_7_2.swc
#   inflating: Aligned/Original/20160929_1013_BGUG_HuC_ltRFP_d6_F1.swc
#   inflating: Aligned/Original/T_190221_10_1.swc
#   inflating: Aligned/Original/T_160527_5_1.swc
#   inflating: Aligned/Original/T_190121_10_3.swc
#   inflating: Aligned/Original/T_200108_9_GFP_1.swc
#   inflating: Aligned/Original/T_190527_1181xBG_15_1.swc
#   inflating: Aligned/Original/T_201208_3_GFP_2.swc
#   inflating: Aligned/Original/T_210211_11_GFP_1.swc
#   inflating: Aligned/Original/FT_T_vmG_6.swc
#   inflating: Aligned/Original/T_150707_14_3_full.swc
#   inflating: Aligned/Original/T_200909_10_GFP_2.swc
#   inflating: Aligned/Original/T_161005_HuCxBG_erk_2_1.swc
#   inflating: Aligned/Original/T_190405_13_1.swc
#   inflating: Aligned/Original/T_150529_354_fixed_3_1b_full_tracing.swc
#   inflating: Aligned/Original/T_221207_7_3.swc
#   inflating: Aligned/Original/T_190121_9_5.swc
#   inflating: Aligned/Original/T_170821_0_1.swc
#   inflating: Aligned/Original/T_200831_19_GFP_2.swc
#   inflating: Aligned/Original/T_170201_18_1.swc
#   inflating: Aligned/Original/20160526_1013_BGUG_HuC_ltRFP_d6_F4.swc
#   inflating: Aligned/Original/T_unres_2016-04-11_fish2_cellB_left_Anna_recalc_selfAND_merged_uncrop.swc
#   inflating: Aligned/Original/T_170119_6_1.swc
#   inflating: Aligned/Original/T_160617_HuCxBG_3_1.swc
#   inflating: Aligned/Original/T_200602_7_GFP_2.swc
#   inflating: Aligned/Original/T_210209_5_GFP_4.swc
#   inflating: Aligned/Original/T_150324_fixed_19_2a_full_tracing.swc
#   inflating: Aligned/Original/T_211025_10_2.swc
#   inflating: Aligned/Original/20160526_1013_BGUG_HuC_ltRFP_d6_F3.swc
#   inflating: Aligned/Original/T_151130_4_1.swc
#   inflating: Aligned/Original/T_200120_9_2.swc
#   inflating: Aligned/Original/T_221210_8_2.swc
#   inflating: Aligned/Original/T_151113_4_2.swc
#   inflating: Aligned/Original/T_201102_22_GFP_2.swc
#   inflating: Aligned/Original/T_190909_7_3.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_11_1.swc
#   inflating: Aligned/Original/T_201106_13_3.swc
#   inflating: Aligned/Original/T_210119_4_GFP_3.swc
#   inflating: Aligned/Original/T_200124_5_3.swc
#   inflating: Aligned/Original/T_191115_3_5.swc
#   inflating: Aligned/Original/T_170303_4_1.swc
#   inflating: Aligned/Original/T_190723_5_1.swc
#   inflating: Aligned/Original/20160922_1013_BGUG_HuC_ltRFP_d6_F3.swc
#   inflating: Aligned/Original/T_18116_1_2.swc
#   inflating: Aligned/Original/T_145_2016-05-29_fish2_left_Anna_recalc_2pSelfAND_merged_uncrop.swc
#   inflating: Aligned/Original/T_230816_12_3.swc
#   inflating: Aligned/Original/T_190613_1181xBG_5_1.swc
#   inflating: Aligned/Original/T_201124_16_GFP_1.swc
#   inflating: Aligned/Original/T_161116_24_1.swc
#   inflating: Aligned/Original/T_160809_16_3.swc
#   inflating: Aligned/Original/20170117_1013_BGUG_HuC_ltRFP_d5_F1.swc
#   inflating: Aligned/Original/T_161116_16_2.swc
#   inflating: Aligned/Original/T_201009_27_GFP_1.swc
#   inflating: Aligned/Original/T_211122_1_1.swc
#   inflating: Aligned/Original/T_190218_11_1.swc
#   inflating: Aligned/Original/T_170821_11_1.swc
#   inflating: Aligned/Original/T_190626_1_2_D.swc
#   inflating: Aligned/Original/T_170627_13_2.swc
#   inflating: Aligned/Original/T_160524_3_2.swc
#   inflating: Aligned/Original/T_200107_8_2.swc
#   inflating: Aligned/Original/T_150324_fixed_9_2_full_tracing.swc
#   inflating: Aligned/Original/T_201229_2_GFP_2.swc
#   inflating: Aligned/Original/T_160607_6_4.swc
#   inflating: Aligned/Original/T_221207_1_1.swc
#   inflating: Aligned/Original/T_190220_1026xBG_7_2.swc
#   inflating: Aligned/Original/T_200818_19_3.swc
#   inflating: Aligned/Original/20160916_1013_BGUG_HuC_ltRFP_d7_F11.swc
#   inflating: Aligned/Original/T_161031_0_3.swc
#   inflating: Aligned/Original/T_170201_5_4.swc
#   inflating: Aligned/Original/T_160502_9_4_complemented.swc
#   inflating: Aligned/Original/T_190523_0_2.swc
#   inflating: Aligned/Original/T_170821_12_2.swc
#   inflating: Aligned/Original/T_210218_8_GFP_1.swc
#   inflating: Aligned/Original/T_190924_7_1.swc
#   inflating: Aligned/Original/20160616_1013_BGUG_HuC_ltRFP_d7_F2.swc
#   inflating: Aligned/Original/FT_T_lG_2.swc
#   inflating: Aligned/Original/T_180201_1_1.swc
#   inflating: Aligned/Original/T_150324_fixed_20_1_full_tracing.swc
#   inflating: Aligned/Original/20170818_1013_BGUG_HuC_ltRFP_d6_F1_Neuron1.swc
#   inflating: Aligned/Original/T_150529_354_fixed_7_3a_full_tracing.swc
#   inflating: Aligned/Original/39_mod_T_160808_F2M2_prey+RF_02.swc
#   inflating: Aligned/Original/T_191212_6_1.swc
#   inflating: Aligned/Original/T_161031_9_2.swc
#   inflating: Aligned/Original/T_191007_16_1.swc
#   inflating: Aligned/Original/T_150324_fixed_11_2_full_tracing.swc
#   inflating: Aligned/Original/T_220311_11_2.swc
#   inflating: Aligned/Original/T_160705_3_4.swc
#   inflating: Aligned/Original/T_190723_12_3.swc
#   inflating: Aligned/Original/T_170327_6_1.swc
#   inflating: Aligned/Original/T_200108_2_GFP_3.swc
#   inflating: Aligned/Original/T_190723_9_1.swc
#   inflating: Aligned/Original/T_170704_7_2.swc
#   inflating: Aligned/Original/T_190924_15_3.swc
#   inflating: Aligned/Original/T_160920_15_3.swc
#   inflating: Aligned/Original/T_190711_13_2.swc
#   inflating: Aligned/Original/T_201110_4_1.swc
#   inflating: Aligned/Original/T_170529_17_2.swc
#   inflating: Aligned/Original/T_211108_7_1.swc
#   inflating: Aligned/Original/T_180111_6_1.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_6_3.swc
#   inflating: Aligned/Original/T_160518_12_4.swc
#   inflating: Aligned/Original/T_161005_HuCxBG_erk_9_2.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_1_1.swc
#   inflating: Aligned/Original/T_160518_10_4.swc
#   inflating: Aligned/Original/T_150529_354_fixed_5_2_full_tracing.swc
#   inflating: Aligned/Original/T_170821_3_2.swc
#   inflating: Aligned/Original/T_190218_18_2.swc
#   inflating: Aligned/Original/T_190426_1181xBG_5_4.swc
#   inflating: Aligned/Original/T_190924_10_1.swc
#   inflating: Aligned/Original/T_150324_fixed_3_2_full_tracing.swc
#   inflating: Aligned/Original/T_180112_11_1.swc
#   inflating: Aligned/Original/T_160809_19_2.swc
#   inflating: Aligned/Original/T_191212_0_3.swc
#   inflating: Aligned/Original/T_150324_fixed_5_3_full_tracing.swc
#   inflating: Aligned/Original/T_160927_7_2.swc
#   inflating: Aligned/Original/F_L_FT_T_81_190304_F4M32.swc
#   inflating: Aligned/Original/T_181102_13_1_Eva.swc
#   inflating: Aligned/Original/T_190221_5_2.swc
#   inflating: Aligned/Original/T_190924_15_2.swc
#   inflating: Aligned/Original/22_mod_T_160719_F5M7_NURPREY_02.swc
#   inflating: Aligned/Original/FT_T_lG_7.swc
#   inflating: Aligned/Original/T_161109_6_1.swc
#   inflating: Aligned/Original/T_190527_1181xBG_13_1.swc
#   inflating: Aligned/Original/T_201124_13_GFP_3.swc
#   inflating: Aligned/Original/T_160502_9_6_complemented.swc
#   inflating: Aligned/Original/T_150609_354_fixed_1_1_full_tracing.swc
#   inflating: Aligned/Original/T_201027_1_GFP_1.swc
#   inflating: Aligned/Original/T_191007_15_3.swc
#   inflating: Aligned/Original/T_201116_20_GFP_3.swc
#   inflating: Aligned/Original/T_160705_9_6.swc
#   inflating: Aligned/Original/T_190206_13_1.swc
#   inflating: Aligned/Original/T_151130_7_1.swc
#   inflating: Aligned/Original/T_161129_23_2.swc
#   inflating: Aligned/Original/T_190125_9_1.swc
#   inflating: Aligned/Original/T_211122_5_2.swc
#   inflating: Aligned/Original/T_190702_317xBG_12_2.swc
#   inflating: Aligned/Original/20161011_1013_BGUG_HuC_ltRFP_d5_F1.swc
#   inflating: Aligned/Original/T_170704_10_3.swc
#   inflating: Aligned/Original/T_190121_10_1.swc
#   inflating: Aligned/Original/T_181102_8_1_Eva.swc
#   inflating: Aligned/Original/T_190909_0_3.swc
#   inflating: Aligned/Original/T_201229_3_GFP_1.swc
#   inflating: Aligned/Original/T_210211_3_GFP_1.swc
#   inflating: Aligned/Original/T_201102_23_1.swc
#   inflating: Aligned/Original/T_190401_5_4.swc
#   inflating: Aligned/Original/20170310_1013_BGUG_HuC_ltRFP_d7_F3.swc
#   inflating: Aligned/Original/T_210414_9_GFP_3.swc
#   inflating: Aligned/Original/3_mod_T_160621_F2M2_loom_02.swc
#   inflating: Aligned/Original/20160907_1013_BGUG_HuC_ltRFP_d6_F8.swc
#   inflating: Aligned/Original/FT_T_lG_3.swc
#   inflating: Aligned/Original/T_160714_1_1.swc
#   inflating: Aligned/Original/T_200325_6_1.swc
#   inflating: Aligned/Original/T_180102_12_1.swc
#   inflating: Aligned/Original/T_190206_20_3.swc
#   inflating: Aligned/Original/20161011_1013_BGUG_HuC_ltRFP_d5_F2_Neuron1.swc
#   inflating: Aligned/Original/T_190626_11_2.swc
#   inflating: Aligned/Original/T_200214_10_2.swc
#   inflating: Aligned/Original/T_151130_13_1.swc
#   inflating: Aligned/Original/T_150714_2_1_full_tracing.swc
#   inflating: Aligned/Original/T_160520_3_2.swc
#   inflating: Aligned/Original/T_190531_3_6.swc
#   inflating: Aligned/Original/T_151130_8_2.swc
#   inflating: Aligned/Original/T_190405_23_3.swc
#   inflating: Aligned/Original/20170111_1013_BGUG_HuC_ltRFP_d5_F1.swc
#   inflating: Aligned/Original/T_16119_5_1.swc
#   inflating: Aligned/Original/T_200406_4_2.swc
#   inflating: Aligned/Original/T_191007a_1_2.swc
#   inflating: Aligned/Original/T_190115_11_2.swc
#   inflating: Aligned/Original/T_170201_10_3.swc
#   inflating: Aligned/Original/T_230111_5_1.swc
#   inflating: Aligned/Original/T_190924_9_1.swc
#   inflating: Aligned/Original/T_170327_11_1.swc
#   inflating: Aligned/Original/T_200818_2_GFP_1.swc
#   inflating: Aligned/Original/20170406_1013_BGUG_HuC_ltRFP_d6_F8.swc
#   inflating: Aligned/Original/5_mod_T_160707_F1M1_loom_02.swc
#   inflating: Aligned/Original/T_150609_354_fixed_4_1a_full_tracing.swc
#   inflating: Aligned/Original/T_19_2016-04-07_fish3_cellA_right_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/20160922_1013_BGUG_HuC_ltRFP_d6_F7.swc
#   inflating: Aligned/Original/F_L_FT_72_T_190218_F4M25.swc
#   inflating: Aligned/Original/T_200903_6_GFP_1.swc
#   inflating: Aligned/Original/T_211122_12_2.swc
#   inflating: Aligned/Original/T_180112_10_3.swc
#   inflating: Aligned/Original/20170520_1013_BGUG_HuC_ltRFP_d7_F7.swc
#   inflating: Aligned/Original/T_161121_15_1.swc
#   inflating: Aligned/Original/T_190527_1181xBG_12_3.swc
#   inflating: Aligned/Original/T_145_2015-12-07_fish2_right_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/T_210301_13_GFP_1.swc
#   inflating: Aligned/Original/T_201229_2_GFP_1.swc
#   inflating: Aligned/Original/T_200909_16_1.swc
#   inflating: Aligned/Original/T_180111_4_3.swc
#   inflating: Aligned/Original/T_151208_21_1.swc
#   inflating: Aligned/Original/T_170210_VGlut_GFP_SYP_6_1.swc
#   inflating: Aligned/Original/T_161121_0_GFP_4.swc
#   inflating: Aligned/Original/T_150527_354_fixed_1_1_full_tracing.swc
#   inflating: Aligned/Original/T_200214_14_1.swc
#   inflating: Aligned/Original/20160927_1013_BGUG_HuC_ltRFP_d6_F2_Neuron3.swc
#   inflating: Aligned/Original/T_201208_6_GFP_1.swc
#   inflating: Aligned/Original/T_161005_HuCxBG_erk_9_4.swc
#   inflating: Aligned/Original/T_161129_2_4.swc
#   inflating: Aligned/Original/T_151110_7_5.swc
#   inflating: Aligned/Original/T_161129_6_1.swc
#   inflating: Aligned/Original/T_201006_2_GFP_1.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_18_2.swc
#   inflating: Aligned/Original/T_190125_8_8.swc
#   inflating: Aligned/Original/T_170201_5_2.swc
#   inflating: Aligned/Original/56_mod_T_170207_F3M9_prey.swc
#   inflating: Aligned/Original/T_16119_5_8.swc
#   inflating: Aligned/Original/T_16119_13_5.swc
#   inflating: Aligned/Original/T_200909_8_GFP_2.swc
#   inflating: Aligned/Original/T_170221_18_1.swc
#   inflating: Aligned/Original/T_190924_27_2.swc
#   inflating: Aligned/Original/T_170601_3_2.swc
#   inflating: Aligned/Original/T_191016_11_4.swc
#   inflating: Aligned/Original/T_160714_3_2.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_2_3.swc
#   inflating: Aligned/Original/T_210203_3_GFP_1.swc
#   inflating: Aligned/Original/T_190121_20_2.swc
#   inflating: Aligned/Original/T_160607_8_1.swc
#   inflating: Aligned/Original/T_16119_5_9.swc
#   inflating: Aligned/Original/T_210218_3_GFP_1.swc
#   inflating: Aligned/Original/17_mod_T_160718_F5M8_loom+dimm_02.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_15_4.swc
#   inflating: Aligned/Original/T_180112_7_1.swc
#   inflating: Aligned/Original/T_210420_2_1.swc
#   inflating: Aligned/Original/20170303_1013_BGUG_HuC_ltRFP_d7_F1.swc
#   inflating: Aligned/Original/T_151130_8_1.swc
#   inflating: Aligned/Original/T_191007_12_1.swc
#   inflating: Aligned/Original/20161011_1013_BGUG_HuC_ltRFP_d5_F2_Neuron2.swc
#   inflating: Aligned/Original/T_160913_HuCxBG_2_1.swc
#   inflating: Aligned/Original/T_190613_1181xBG_5_4.swc
#   inflating: Aligned/Original/T_201116_9_GFP_2.swc
#   inflating: Aligned/Original/T_150722_5_3_full_tracing.swc
#   inflating: Aligned/Original/T_201023_7_super_GFP_1.swc
#   inflating: Aligned/Original/T_170201_18_3.swc
#   inflating: Aligned/Original/20161123_1013_BGUG_HuC_ltRFP_d5_F1_Neuron1.swc
#   inflating: Aligned/Original/20161123_1013_BGUG_HuC_ltRFP_d5_F1_Neuron2.swc
#   inflating: Aligned/Original/T_160406_4_2.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_15_2_SC_projection.swc
#   inflating: Aligned/Original/T_190405_10_2.swc
#   inflating: Aligned/Original/T_201222_7_GFP_3.swc
#   inflating: Aligned/Original/T_210317_2_GFP_1.swc
#   inflating: Aligned/Original/T_160708_22_4.swc
#   inflating: Aligned/Original/20161213_1013_BGUG_HuC_ltRFP_d6_F2_Neuron1.swc
#   inflating: Aligned/Original/T_191016_6_1.swc
#   inflating: Aligned/Original/T_200824_11_GFP_1.swc
#   inflating: Aligned/Original/T_190527_1181xBG_12_4.swc
#   inflating: Aligned/Original/T_190131_9_5.swc
#   inflating: Aligned/Original/T_190405_12_1.swc
#   inflating: Aligned/Original/T_190131_12_3.swc
#   inflating: Aligned/Original/T_160920_6_2.swc
#   inflating: Aligned/Original/T_170627_13_5.swc
#   inflating: Aligned/Original/T_201222_6_GFP_1.swc
#   inflating: Aligned/Original/T_200131_3_2.swc
#   inflating: Aligned/Original/20161219_1013_BGUG_HuC_ltRFP_d5_F3.swc
#   inflating: Aligned/Original/T_190527_1181xBG_17_2.swc
#   inflating: Aligned/Original/T_170201_10_1.swc
#   inflating: Aligned/Original/T_16119_19_1.swc
#   inflating: Aligned/Original/T_170704_3_2.swc
#   inflating: Aligned/Original/T_160708_22_3.swc
#   inflating: Aligned/Original/T_160705_16_3.swc
#   inflating: Aligned/Original/T_200831_9_1.swc
#   inflating: Aligned/Original/20170708_1013_BGUG_HuC_ltRFP_d7_F2.swc
#   inflating: Aligned/Original/T_145_2016-05-17_fish1_cellA_right_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/T_190125_0_1.swc
#   inflating: Aligned/Original/T_200325_6_2.swc
#   inflating: Aligned/Original/T_210302_7_1.swc
#   inflating: Aligned/Original/T_201009_15_GFP_1.swc
#   inflating: Aligned/Original/T_200120_0_1.swc
#   inflating: Aligned/Original/T_160705_14_3.swc
#   inflating: Aligned/Original/T_201229_8_GFP_1.swc
#   inflating: Aligned/Original/T_200522_8_1.swc
#   inflating: Aligned/Original/T_201111_11_1.swc
#   inflating: Aligned/Original/T_200916_1_1.swc
#   inflating: Aligned/Original/T_191204_2_1.swc
#   inflating: Aligned/Original/T_190523_1_1_M.swc
#   inflating: Aligned/Original/T_200710_20_1.swc
#   inflating: Aligned/Original/T_150518_10_3b_full_tracing.swc
#   inflating: Aligned/Original/T_150324_fixed_8_1b_full_tracing.swc
#   inflating: Aligned/Original/20170224_1013_BGUG_HuC_ltRFP_d7_F7.swc
#   inflating: Aligned/Original/20160922_1013_BGUG_HuC_ltRFP_d6_F7_Neuron2.swc
#   inflating: Aligned/Original/20160928_1013_BGUG_HuC_ltRFP_d5_F3_Neuron3.swc
#   inflating: Aligned/Original/T_161116_23_3.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_6_1.swc
#   inflating: Aligned/Original/T_160812_16_1.swc
#   inflating: Aligned/Original/T_170201_3_2.swc
#   inflating: Aligned/Original/T_190218_6_1.swc
#   inflating: Aligned/Original/T_160905_7_3.swc
#   inflating: Aligned/Original/T_160607_18_2.swc
#   inflating: Aligned/Original/53_mod_T_170206_F1M4_prey.swc
#   inflating: Aligned/Original/T_161116_5_2.swc
#   inflating: Aligned/Original/T_160610_HuCxBG_22_4_complemented.swc
#   inflating: Aligned/Original/T_160920_20_3.swc
#   inflating: Aligned/Original/T_16119_10_6.swc
#   inflating: Aligned/Original/T_190702_317xBG_5_2.swc
#   inflating: Aligned/Original/T_160518_8_4.swc
#   inflating: Aligned/Original/T_161129_22_1.swc
#   inflating: Aligned/Original/T_200214_9_1.swc
#   inflating: Aligned/Original/T_151208_14_2.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_23_2.swc
#   inflating: Aligned/Original/T_170201_6_1.swc
#   inflating: Aligned/Original/T_160502_16_1.swc
#   inflating: Aligned/Original/T_200522_8_3.swc
#   inflating: Aligned/Original/T_161010_19_1.swc
#   inflating: Aligned/Original/T_230111_4_6.swc
#   inflating: Aligned/Original/T_unres_2016-06-04_fish1_cellB_left_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/T_170714_11_1.swc
#   inflating: Aligned/Original/T_190812_10_1.swc
#   inflating: Aligned/Original/T_190206_5_1.swc
#   inflating: Aligned/Original/T_180604_14_1.swc
#   inflating: Aligned/Original/T_161005_HuCxBG_erk_14_2.swc
#   inflating: Aligned/Original/T_191128_16_1.swc
#   inflating: Aligned/Original/T_160705_17_3.swc
#   inflating: Aligned/Original/T_190702_317xBG_1_1.swc
#   inflating: Aligned/Original/T_170529_5_2.swc
#   inflating: Aligned/Original/T_161129_9_6.swc
#   inflating: Aligned/Original/T_190527_1181xBG_18_1.swc
#   inflating: Aligned/Original/T_190401_7_2.swc
#   inflating: Aligned/Original/T_210126_4_GFP_2.swc
#   inflating: Aligned/Original/T_230816_2_3.swc
#   inflating: Aligned/Original/T_201208_9_GFP_1.swc
#   inflating: Aligned/Original/T_201006_22_GFP_2.swc
#   inflating: Aligned/Original/T_200108_9_GFP_3.swc
#   inflating: Aligned/Original/T_200115_16_1.swc
#   inflating: Aligned/Original/T_145_2016-03-25_fish1_cellA_right_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/T_170821_10_2.swc
#   inflating: Aligned/Original/T_190918_3_1_M.swc
#   inflating: Aligned/Original/T_200916_4_3.swc
#   inflating: Aligned/Original/T_160705_3_2.swc
#   inflating: Aligned/Original/20161125_1013_BGUG_HuC_ltRFP_d7_F3.swc
#   inflating: Aligned/Original/T_200710_4_1.swc
#   inflating: Aligned/Original/T_170327_14_1.swc
#   inflating: Aligned/Original/T_190924_24_1.swc
#   inflating: Aligned/Original/T_201009_9_GFP_1.swc
#   inflating: Aligned/Original/T_180604_12_1.swc
#   inflating: Aligned/Original/T_160721_HuCxBG_18_1.swc
#   inflating: Aligned/Original/T_160617_HuCxBG_7__complemented.swc
#   inflating: Aligned/Original/T_161121_HuCxBG_18_2.swc
#   inflating: Aligned/Original/T_190312_9_1.swc
#   inflating: Aligned/Original/20160912_1013_BGUG_HuC_ltRFP_d6_F3.swc
#   inflating: Aligned/Original/T_16119_11_2.swc
#   inflating: Aligned/Original/T_201222_5_GFP_1.swc
#   inflating: Aligned/Original/F_L_FT_T_104_200225_F6M26.swc
#   inflating: Aligned/Original/20160928_1013_BGUG_HuC_ltRFP_d7_F2.swc
#   inflating: Aligned/Original/T_160906_4_2.swc
#   inflating: Aligned/Original/T_160502_8_3_complemented.swc
#   inflating: Aligned/Original/T_190426_1181xBG_0_2.swc
#   inflating: Aligned/Original/T_190218_15_1.swc
#   inflating: Aligned/Original/T_190221_18_1.swc
#   inflating: Aligned/Original/T_230816_2_1.swc
#   inflating: Aligned/Original/T_170714_8_1.swc
#   inflating: Aligned/Original/T_190121_21_2.swc
#   inflating: Aligned/Original/20160919_1013_BGUG_HuC_ltRFP_d5_F2_Neuron1.swc
#   inflating: Aligned/Original/67_mod_T_160804_F2M5_loom+dimm+df_02.swc
#   inflating: Aligned/Original/T_151110_1_2.swc
#   inflating: Aligned/Original/T_190711_5_2.swc
#   inflating: Aligned/Original/T_16119_9_4.swc
#   inflating: Aligned/Original/T_190924_18_1.swc
#   inflating: Aligned/Original/T_161124_20_1.swc
#   inflating: Aligned/Original/T_161010_4_1.swc
#   inflating: Aligned/Original/T_190401_6_3.swc
#   inflating: Aligned/Original/T_151208_22_1.swc
#   inflating: Aligned/Original/20161006_1013_BGUG_HuC_ltRFP_d7_F4.swc
#   inflating: Aligned/Original/T_161005_HuCxBG_erk_2_2.swc
#   inflating: Aligned/Original/T_181102_4_1.swc
#   inflating: Aligned/Original/T_170327_20_1.swc
#   inflating: Aligned/Original/T_160920_24_1.swc
#   inflating: Aligned/Original/T_190218_9_2.swc
#   inflating: Aligned/Original/T_190918_11_1.swc
#   inflating: Aligned/Original/T_201229_5_GFP_1.swc
#   inflating: Aligned/Original/T_161129_7_3.swc
#   inflating: Aligned/Original/20161205_1013_BGUG_HuC_ltRFP_d5_F6.swc
#   inflating: Aligned/Original/T_190131_11_1.swc
#   inflating: Aligned/Original/T_190924_19_1.swc
#   inflating: Aligned/Original/F_L_FT_75_T_190219_F3M18.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_13_3.swc
#   inflating: Aligned/Original/T_191115_0_5.swc
#   inflating: Aligned/Original/T_190312_8_2.swc
#   inflating: Aligned/Original/T_190718_6_3.swc
#   inflating: Aligned/Original/T_190405_13_4.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_18_1.swc
#   inflating: Aligned/Original/T_230816_11_1.swc
#   inflating: Aligned/Original/T_190918_26_1.swc
#   inflating: Aligned/Original/T_211025_4_1.swc
#   inflating: Aligned/Original/T_201023_14_GFP_2.swc
#   inflating: Aligned/Original/T_160714_1_2.swc
#   inflating: Aligned/Original/T_161116_13_2.swc
#   inflating: Aligned/Original/T_151110_7_1.swc
#   inflating: Aligned/Original/F_L_FT_73_T_190218_F5M32.swc
#   inflating: Aligned/Original/T_160721_8_2.swc
#   inflating: Aligned/Original/T_201124_15_GFP_1.swc
#   inflating: Aligned/Original/20170224_1013_BGUG_HuC_ltRFP_d7_F1.swc
#   inflating: Aligned/Original/T_191016_0_1_M.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_10_3.swc
#   inflating: Aligned/Original/T_201006_22_GFP_1.swc
#   inflating: Aligned/Original/T_190401_8_2.swc
#   inflating: Aligned/Original/20161220_1013_BGUG_HuC_ltRFP_d6_F1.swc
#   inflating: Aligned/Original/T_191220_3_1.swc
#   inflating: Aligned/Original/T_201222_6_GFP_2.swc
#   inflating: Aligned/Original/T_190924_2_1.swc
#   inflating: Aligned/Original/20160919_1013_BGUG_HuC_ltRFP_d5_F1_Neuron2.swc
#   inflating: Aligned/Original/25_mod_T_160725_F3M8_loom+dimm_02.swc
#   inflating: Aligned/Original/T_190626_0_1.swc
#   inflating: Aligned/Original/T_161129_15_2.swc
#   inflating: Aligned/Original/T_190115_3_3.swc
#   inflating: Aligned/Original/T_161010_12_1.swc
#   inflating: Aligned/Original/T_160913_HuCxBG_2_3.swc
#   inflating: Aligned/Original/T_161031_21_1.swc
#   inflating: Aligned/Original/T_190125_0_2.swc
#   inflating: Aligned/Original/T_210211_8_GFP_1.swc
#   inflating: Aligned/Original/T_191212_7_2.swc
#   inflating: Aligned/Original/T_170119_1_1.swc
#   inflating: Aligned/Original/T_200912_12_GFP_1.swc
#   inflating: Aligned/Original/T_190125_16_9.swc
#   inflating: Aligned/Original/T_160705_1_2.swc
#   inflating: Aligned/Original/T_200831_15_1.swc
#   inflating: Aligned/Original/T_190115_7_2.swc
#   inflating: Aligned/Original/T_190115_10_3.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_10_2.swc
#   inflating: Aligned/Original/T_181008_3_1_Eva.swc
#   inflating: Aligned/Original/T_160809_8_3.swc
#   inflating: Aligned/Original/T_190125_3_4.swc
#   inflating: Aligned/Original/T_201116_4_GFP_1.swc
#   inflating: Aligned/Original/T_160714_12_1.swc
#   inflating: Aligned/Original/T_220311_5_1.swc
#   inflating: Aligned/Original/T_161129_19_4.swc
#   inflating: Aligned/Original/20170513_1013_BGUG_HuC_ltRFP_d7_F7.swc
#   inflating: Aligned/Original/T_170210_VGlut_GFP_SYP_7_1.swc
#   inflating: Aligned/Original/T_151110_3_1.swc
#   inflating: Aligned/Original/T_191007a_4_1.swc
#   inflating: Aligned/Original/T_200824_2_GFP_2.swc
#   inflating: Aligned/Original/T_200831_3_1.swc
#   inflating: Aligned/Original/T_190121_9_1.swc
#   inflating: Aligned/Original/T_190218_2_1.swc
#   inflating: Aligned/Original/T_170704_2_3.swc
#   inflating: Aligned/Original/T_170221_6_1.swc
#   inflating: Aligned/Original/T_181008_15_1.swc
#   inflating: Aligned/Original/T_200710_7_2.swc
#   inflating: Aligned/Original/T_200912_22_2.swc
#   inflating: Aligned/Original/T_191213_6_1.swc
#   inflating: Aligned/Original/T_221207_7_1.swc
#   inflating: Aligned/Original/T_190909_3_4.swc
#   inflating: Aligned/Original/T_170627_3_1.swc
#   inflating: Aligned/Original/T_16119_5_6.swc
#   inflating: Aligned/Original/T_200831_13_GFP_2.swc
#   inflating: Aligned/Original/T_170119_15_2.swc
#   inflating: Aligned/Original/F_L_FT_T_113_200226_F7M21.swc
#   inflating: Aligned/Original/T_210209_3_GFP_2.swc
#   inflating: Aligned/Original/T_161121_HuCxBG_11_1.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_1_1.swc
#   inflating: Aligned/Original/T_200120_17_2.swc
#   inflating: Aligned/Original/T_221210_12_1.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_4_1.swc
#   inflating: Aligned/Original/T_210119_7_GFP_2.swc
#   inflating: Aligned/Original/T_191119_17_1.swc
#   inflating: Aligned/Original/T_160527_3_1.swc
#   inflating: Aligned/Original/T_190312_0_1.swc
#   inflating: Aligned/Original/T_200818_22_GFP_2.swc
#   inflating: Aligned/Original/T_160704_5_2.swc
#   inflating: Aligned/Original/T_190401_4_2.swc
#   inflating: Aligned/Original/T_96_2016-06-07_fish2_cellB_left_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/T_210218_9_GFP_1.swc
#   inflating: Aligned/Original/T_190125_8_7.swc
#   inflating: Aligned/Original/T_161129_23_1.swc
#   inflating: Aligned/Original/20170805_1013_BGUG_HuC_ltRFP_d7_F4.swc
#   inflating: Aligned/Original/T_190121_8_1.swc
#   inflating: Aligned/Original/T_150901_1_4_full_tracing.swc
#   inflating: Aligned/Original/T_16119_13_6.swc
#   inflating: Aligned/Original/F_L_FT_T_95_200224_F8M42.swc
#   inflating: Aligned/Original/T_160520_1_3.swc
#   inflating: Aligned/Original/20160922_1013_BGUG_HuC_ltRFP_d6_F4.swc
#   inflating: Aligned/Original/T_151124_2_1.swc
#   inflating: Aligned/Original/T_160812_5_4.swc
#   inflating: Aligned/Original/T_160704_1_2.swc
#   inflating: Aligned/Original/T_201124_21_GFP_1.swc
#   inflating: Aligned/Original/T_160714_7_1.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_2_2.swc
#   inflating: Aligned/Original/T_161031_1_1.swc
#   inflating: Aligned/Original/T_181026_5_1_Eva.swc
#   inflating: Aligned/Original/T_16119_10_2.swc
#   inflating: Aligned/Original/T_160410_HuCxBG_4_1_complemented.swc
#   inflating: Aligned/Original/T_221207_12_2.swc
#   inflating: Aligned/Original/T_190401_0_1.swc
#   inflating: Aligned/Original/T_16119_20_2.swc
#   inflating: Aligned/Original/T_190718_6_4.swc
#   inflating: Aligned/Original/T_160812_23_4.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_13_5.swc
#   inflating: Aligned/Original/T_190613_1181xBG_2_1.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_3_3.swc
#   inflating: Aligned/Original/20170313_1013_BGUG_HuC_ltRFP_d5_F6.swc
#   inflating: Aligned/Original/T_170327_19_1.swc
#   inflating: Aligned/Original/T_190924_28_1.swc
#   inflating: Aligned/Original/T_160809_16_2.swc
#   inflating: Aligned/Original/T_190702_317xBG_11_1_M.swc
#   inflating: Aligned/Original/T_200124_3_1.swc
#   inflating: Aligned/Original/T_161010_13_1.swc
#   inflating: Aligned/Original/T_unres_2016-06-22_fish3_cellB_right_Anna_recalc_selfAND_merged_uncrop.swc
#   inflating: Aligned/Original/T_190125_12_5.swc
#   inflating: Aligned/Original/FT_T_mdG_T5.swc
#   inflating: Aligned/Original/T_180604_11_2.swc
#   inflating: Aligned/Original/T_161116_25_1.swc
#   inflating: Aligned/Original/T_190131_9_3.swc
#   inflating: Aligned/Original/T_190121_4_1.swc
#   inflating: Aligned/Original/T_161121_HuCxBG_7_3.swc
#   inflating: Aligned/Original/T_161010_4_2.swc
#   inflating: Aligned/Original/T_191007_15_1.swc
#   inflating: Aligned/Original/T_190125_6_4.swc
#   inflating: Aligned/Original/T_200710_16_1.swc
#   inflating: Aligned/Original/T_161124_17_1.swc
#   inflating: Aligned/Original/T_160906_7_1.swc
#   inflating: Aligned/Original/T_190220_1026xBG_7_1.swc
#   inflating: Aligned/Original/20170406_1013_BGUG_HuC_ltRFP_d6_F6.swc
#   inflating: Aligned/Original/T_190218_0_4.swc
#   inflating: Aligned/Original/T_190702_317xBG_18_1.swc
#   inflating: Aligned/Original/T_190718_13_4.swc
#   inflating: Aligned/Original/T_190125_8_2.swc
#   inflating: Aligned/Original/20170901_1013_BGUG_HuC_ltRFP_d6_F1_Neuron2.swc
#   inflating: Aligned/Original/T_170303_6_1.swc
#   inflating: Aligned/Original/T_160809_3_1.swc
#   inflating: Aligned/Original/T_170704_7_3.swc
#   inflating: Aligned/Original/T_210211_1_GFP_1.swc
#   inflating: Aligned/Original/T_160809_19_1.swc
#   inflating: Aligned/Original/T_190121_3_6.swc
#   inflating: Aligned/Original/T_160610_HuCxBG_8_6_complemented.swc
#   inflating: Aligned/Original/T_160906_4_1.swc
#   inflating: Aligned/Original/T_161129_6_2.swc
#   inflating: Aligned/Original/20161205_1013_BGUG_HuC_ltRFP_d5_F7.swc
#   inflating: Aligned/Original/T_170303_15_1.swc
#   inflating: Aligned/Original/FT_T_maG_2.swc
#   inflating: Aligned/Original/T_201111_12_1.swc
#   inflating: Aligned/Original/T_160527_19_1.swc
#   inflating: Aligned/Original/T_180111_1_1.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_7_2.swc
#   inflating: Aligned/Original/T_190812_23_1.swc
#   inflating: Aligned/Original/T_161005_HuCxBG_erk_7_1.swc
#   inflating: Aligned/Original/T_170327_12_1.swc
#   inflating: Aligned/Original/T_190221_4_2.swc
#   inflating: Aligned/Original/20161005_1013_BGUG_HuC_ltRFP_d6_F5_Neuron2.swc
#   inflating: Aligned/Original/20170310_1013_BGUG_HuC_ltRFP_d7_F6_Neuron2.swc
#   inflating: Aligned/Original/20170506_1013_BGUG_HuC_ltRFP_d5_F5.swc
#   inflating: Aligned/Original/T_161109_8_1.swc
#   inflating: Aligned/Original/T_190121_13_2.swc
#   inflating: Aligned/Original/20160916_1013_BGUG_HuC_ltRFP_d7_F6.swc
#   inflating: Aligned/Original/T_161129_19_1.swc
#   inflating: Aligned/Original/T_170704_10_1.swc
#   inflating: Aligned/Original/T_191017_2_1.swc
#   inflating: Aligned/Original/T_160812_8_1.swc
#   inflating: Aligned/Original/43_mod_T_160809_F2M3_liTekt_neuropil_loom+dimm+df_02.swc
#   inflating: Aligned/Original/T_151110_5_2.swc
#   inflating: Aligned/Original/T_170714_7_2.swc
#   inflating: Aligned/Original/T_200124_9_1.swc
#   inflating: Aligned/Original/T_160812_23_5.swc
#   inflating: Aligned/Original/T_170327_5_1.swc
#   inflating: Aligned/Original/T_161116_8_1.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_5_2.swc
#   inflating: Aligned/Original/T_160520_12_1.swc
#   inflating: Aligned/Original/T_161116_7_2.swc
#   inflating: Aligned/Original/T_190531_0_1.swc
#   inflating: Aligned/Original/T_190711_2_1.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_23_1.swc
#   inflating: Aligned/Original/T_190613_1181xBG_1_1.swc
#   inflating: Aligned/Original/T_160809_11_1.swc
#   inflating: Aligned/Original/T_200831_3_2.swc
#   inflating: Aligned/Original/T_161005_HuCxBG_erk_15_2.swc
#   inflating: Aligned/Original/T_160524_7_1.swc
#   inflating: Aligned/Original/T_191011_0_1.swc
#   inflating: Aligned/Original/T_210211_6_GFP_1.swc
#   inflating: Aligned/Original/T_150324_fixed_13_1_full_tracing.swc
#   inflating: Aligned/Original/T_230816_4_1.swc
#   inflating: Aligned/Original/20160927_1013_BGUG_HuC_ltRFP_d6_F9.swc
#   inflating: Aligned/Original/T_161109_3_1.swc
#   inflating: Aligned/Original/T_200818_11_3.swc
#   inflating: Aligned/Original/T_211122_9_2.swc
#   inflating: Aligned/Original/T_210414_5_GFP_1.swc
#   inflating: Aligned/Original/T_160527_1_3.swc
#   inflating: Aligned/Original/T_160527_5_2.swc
#   inflating: Aligned/Original/T_200818_10_GFP_1.swc
#   inflating: Aligned/Original/T_160714_16_2.swc
#   inflating: Aligned/Original/T_160809_3_2.swc
#   inflating: Aligned/Original/T_190711_4_1.swc
#   inflating: Aligned/Original/F_L_FT_T_89_190305_F6M14.swc
#   inflating: Aligned/Original/T_201124_29_GFP_1.swc
#   inflating: Aligned/Original/T_190213_10_1.swc
#   inflating: Aligned/Original/T_161026_1_2.swc
#   inflating: Aligned/Original/T_200124_11_1.swc
#   inflating: Aligned/Original/T_160920_22_1.swc
#   inflating: Aligned/Original/T_200903_7_GFP_1.swc
#   inflating: Aligned/Original/T_191016_10_3.swc
#   inflating: Aligned/Original/T_190115_24_3.swc
#   inflating: Aligned/Original/20160916_1013_BGUG_HuC_ltRFP_d7_F14_Neuron1.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_6_1.swc
#   inflating: Aligned/Original/T_16119_9_1.swc
#   inflating: Aligned/Original/T_191007_13_2_M.swc
#   inflating: Aligned/Original/T_150304_2_3_d.swc
#   inflating: Aligned/Original/20170506_1013_BGUG_HuC_ltRFP_d5_F8_Neuron2.swc
#   inflating: Aligned/Original/T_190312_0_2.swc
#   inflating: Aligned/Original/T_200909_12_1.swc
#   inflating: Aligned/Original/T_190401_2_1.swc
#   inflating: Aligned/Original/T_160906_11_1.swc
#   inflating: Aligned/Original/T_190812_2_1.swc
#   inflating: Aligned/Original/T_160920_18_1.swc
#   inflating: Aligned/Original/T_190131_10_2.swc
#   inflating: Aligned/Original/T_200708_7_1.swc
#   inflating: Aligned/Original/T_190426_1181xBG_2_1.swc
#   inflating: Aligned/Original/T_190125_0_5.swc
#   inflating: Aligned/Original/T_160527_17_2.swc
#   inflating: Aligned/Original/T_170529_24_1.swc
#   inflating: Aligned/Original/T_150518_1_1a_full_tracing.swc
#   inflating: Aligned/Original/T_160610_HuCxBG_19_1.swc
#   inflating: Aligned/Original/T_211108_4_1.swc
#   inflating: Aligned/Original/20160720_1013_BGUG_HuC_ltRFP_d6_F3.swc
#   inflating: Aligned/Original/T_200916_4_2.swc
#   inflating: Aligned/Original/T_160721_HuCxBG_3_1.swc
#   inflating: Aligned/Original/20161005_1013_BGUG_HuC_ltRFP_d6_F12.swc
#   inflating: Aligned/Original/T_160812_24_2.swc
#   inflating: Aligned/Original/T_190711_6_1.swc
#   inflating: Aligned/Original/T_160913_HuCxBG_3_1.swc
#   inflating: Aligned/Original/T_160721_HuCxBG_7_1.swc
#   inflating: Aligned/Original/20160927_1013_BGUG_HuC_ltRFP_d6_F7.swc
#   inflating: Aligned/Original/T_161019_0_1.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_8_2.swc
#   inflating: Aligned/Original/T_150722_4_3_full_tracing.swc
#   inflating: Aligned/Original/T_170529_11_3.swc
#   inflating: Aligned/Original/T_220311_4_1.swc
#   inflating: Aligned/Original/T_150324_fixed_16_2_full_tracing.swc
#   inflating: Aligned/Original/T_210317_7_GFP_1.swc
#   inflating: Aligned/Original/T_190702_317xBG_19_1_M.swc
#   inflating: Aligned/Original/20161011_1013_BGUG_HuC_ltRFP_d5_F6_Neuron1.swc
#   inflating: Aligned/Original/T_200120_1_1.swc
#   inflating: Aligned/Original/T_190613_1181xBG_3_1.swc
#   inflating: Aligned/Original/T_151110_7_3.swc
#   inflating: Aligned/Original/T_150508_fixed_55m_9_1_full_tracing.swc
#   inflating: Aligned/Original/T_200903_11_GFP_1.swc
#   inflating: Aligned/Original/20161123_1013_BGUG_HuC_ltRFP_d5_F5.swc
#   inflating: Aligned/Original/T_161116_14_2.swc
#   inflating: Aligned/Original/T_201102_21_GFP_1.swc
#   inflating: Aligned/Original/T_170627_5_1.swc
#   inflating: Aligned/Original/T_160610_HuCxBG_1_1.swc
#   inflating: Aligned/Original/T_200120_2_1.swc
#   inflating: Aligned/Original/T_17_2016-04-05_fish1_cellA_right_Anna_recalc_OR_merged_uncrop.swc
#   inflating: Aligned/Original/T_151113_5_5.swc
#   inflating: Aligned/Original/T_210302_4_GFP_1.swc
#   inflating: Aligned/Original/20160623_1013_BGUG_HuC_ltRFP_d6_F4.swc
#   inflating: Aligned/Original/T_190531_8_1.swc
#   inflating: Aligned/Original/T_160705_5_1.swc
#   inflating: Aligned/Original/T_170714_10_1.swc
#   inflating: Aligned/Original/T_161121_7_1.swc
#   inflating: Aligned/Original/T_201102_1_GFP_1.swc
#   inflating: Aligned/Original/T_210211_8_GFP_2.swc
#   inflating: Aligned/Original/T_191007_8_3.swc
#   inflating: Aligned/Original/T_160610_HuCxBG_8_4_complemented.swc
#   inflating: Aligned/Original/T_180102_6_3.swc
#   inflating: Aligned/Original/T_160714_2_2.swc
#   inflating: Aligned/Original/T_190702_317xBG_16_1.swc
#   inflating: Aligned/Original/T_200214_22_1.swc
#   inflating: Aligned/Original/T_150304_1_3.swc
#   inflating: Aligned/Original/T_191011_2_2_M.swc
#   inflating: Aligned/Original/20160913_1013_BGUG_HuC_ltRFP_d7_F1.swc
#   inflating: Aligned/Original/T_161116_24_2.swc
#   inflating: Aligned/Original/T_200818_17_4.swc
#   inflating: Aligned/Original/T_200120_10_2.swc
#   inflating: Aligned/Original/T_190426_1181xBG_10_1.swc
#   inflating: Aligned/Original/T_190131_8_5.swc
#   inflating: Aligned/Original/T_200912_15_GFP_1.swc
#   inflating: Aligned/Original/T_180219_6_1.swc
#   inflating: Aligned/Original/T_210302_1_GFP_1.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_2_5.swc
#   inflating: Aligned/Original/T_210203_1_GFP_3.swc
#   inflating: Aligned/Original/T_161121_6_1.swc
#   inflating: Aligned/Original/T_190924_32_2.swc
#   inflating: Aligned/Original/T_200708_7_3.swc
#   inflating: Aligned/Original/T_211025_3_2.swc
#   inflating: Aligned/Original/T_160913_HuCxBG_1_4.swc
#   inflating: Aligned/Original/T_18116_1_3.swc
#   inflating: Aligned/Original/T_211025_7_1.swc
#   inflating: Aligned/Original/20160929_1013_BGUG_HuC_ltRFP_d6_F8_Neuron2.swc
#   inflating: Aligned/Original/T_170210_4_1.swc
#   inflating: Aligned/Original/T_190812_14_1.swc
#   inflating: Aligned/Original/T_160705_7_3.swc
#   inflating: Aligned/Original/T_160527_14_2.swc
#   inflating: Aligned/Original/T_161019_13_2.swc
#   inflating: Aligned/Original/T_190206_19_1.swc
#   inflating: Aligned/Original/T_190702_317xBG_10_1.swc
#   inflating: Aligned/Original/T_151130_14_2_complemented.swc
#   inflating: Aligned/Original/20170228_1013_BGUG_HuC_ltRFP_d5_F1.swc
#   inflating: Aligned/Original/T_200818_21_3.swc
#   inflating: Aligned/Original/T_161116_8_2.swc
#   inflating: Aligned/Original/T_150901_5_3_full_tracing.swc
#   inflating: Aligned/Original/20161125_1013_BGUG_HuC_ltRFP_d7_F2_Neuron2.swc
#   inflating: Aligned/Original/T_161005_HuCxBG_erk_15_4.swc
#   inflating: Aligned/Original/T_170821_14_2.swc
#   inflating: Aligned/Original/T_190812_14_2_M.swc
#   inflating: Aligned/Original/T_181008_16_2_Eva.swc
#   inflating: Aligned/Original/T_191016_5_2.swc
#   inflating: Aligned/Original/T_150609_354_fixed_10_1_full_tracing.swc
#   inflating: Aligned/Original/T_191204_0_4.swc
#   inflating: Aligned/Original/20170609_1013_BGUG_HuC_ltRFP_d7_F3_Neuron2.swc
#   inflating: Aligned/Original/T_161116_22_2.swc
#   inflating: Aligned/Original/T_151208_17_2.swc
#   inflating: Aligned/Original/T_190812_6_2.swc
#   inflating: Aligned/Original/T_201222_1_GFP_2.swc
#   inflating: Aligned/Original/T_161019_14_8.swc
#   inflating: Aligned/Original/T_190121_5_1.swc
#   inflating: Aligned/Original/T_170529_19_1.swc
#   inflating: Aligned/Original/F_L_FT_T_109_200226_F3M8.swc
#   inflating: Aligned/Original/FT_T_lG_6.swc
#   inflating: Aligned/Original/T_160502_6_1.swc
#   inflating: Aligned/Original/T_201102_4_GFP_2.swc
#   inflating: Aligned/Original/T_190131_12_1.swc
#   inflating: Aligned/Original/T_190523_6_1.swc
#   inflating: Aligned/Original/T_200728_2_GFP_2.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_19_1.swc
#   inflating: Aligned/Original/F_L_FT_T_101_200225_F3M14.swc
#   inflating: Aligned/Original/T_190401_2_3.swc
#   inflating: Aligned/Original/T_201222_4_GFP_3.swc
#   inflating: Aligned/Original/T_170704_19_4.swc
#   inflating: Aligned/Original/T_160520_1_4.swc
#   inflating: Aligned/Original/T_170119_16_2.swc
#   inflating: Aligned/Original/T_160502_2_3_corrected.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_4_1.swc
#   inflating: Aligned/Original/T_200818_9_GFP_3.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_3_1.swc
#   inflating: Aligned/Original/T_180112_2_2.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_10_1.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_9_1.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_17_1.swc
#   inflating: Aligned/Original/T_160610_HuCxBG_15_1_complemented.swc
#   inflating: Aligned/Original/T_191016_10_2.swc
#   inflating: Aligned/Original/T_191213_6_3.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_16_2.swc
#   inflating: Aligned/Original/T_161124_HuCxBG_19_3.swc
#   inflating: Aligned/Original/T_161031_18_3.swc
#   inflating: Aligned/Original/T_190218_12_1.swc
#   inflating: Aligned/Original/T_170119_11_1.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_0_2.swc
#   inflating: Aligned/Original/20160720_1013_BGUG_HuC_ltRFP_d6_F8_Neuron1.swc
#   inflating: Aligned/Original/20160906_1013_BGUG_HuC_ltRFP_d5_F2.swc
#   inflating: Aligned/Original/T_150407_7_1_full_tracing.swc
#   inflating: Aligned/Original/68_mod_T_160808_F5M5_prey_02.swc
#   inflating: Aligned/Original/T_170201_3_3.swc
#   inflating: Aligned/Original/T_161121_HuCxBG_10_2.swc
#   inflating: Aligned/Original/T_160510_Image7_Stitch_2.swc
#   inflating: Aligned/Original/T_191119_7_1.swc
#   inflating: Aligned/Original/T_170601_13_1.swc
#   inflating: Aligned/Original/T_161109_15_1.swc
#   inflating: Aligned/Original/T_200909_15_GFP_2.swc
#   inflating: Aligned/Original/T_190401_5_1.swc
#   inflating: Aligned/Original/T_170704_19_2.swc
#   inflating: Aligned/Original/T_170627_10_3.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_7_1.swc
#   inflating: Aligned/Original/T_161026_HuCxBG_erksyp_0_1.swc
#   inflating: Aligned/Original/T_190131_7_1.swc
#   inflating: Aligned/Original/T_161129_15_1.swc
#   inflating: Aligned/Original/20160519_1013_BGUG_HuC_ltRFP_d6_F1.swc
#   inflating: Aligned/Original/T_190426_1181xBG_6_1_MK.swc
#   inflating: Aligned/Original/T_170627_2_2.swc
#   inflating: Aligned/Original/T_191128_0_1.swc
#   inflating: Aligned/Original/T_160610_HuCxBG_16_1.swc
#   inflating: Aligned/Original/T_160502_4_1_corrected.swc
#   inflating: Aligned/Original/T_190719_4_1.swc
#   inflating: Aligned/Original/T_151130_2_2.swc
#   inflating: Aligned/Original/T_190218_10_1.swc
#   inflating: Aligned/Original/T_190909_2_1.swc
#   inflating: Aligned/Original/T_1600520_8_1.swc
#   inflating: Aligned/Original/T_160406_5b_1.swc
#   inflating: Aligned/Original/T_200818_8_GFP_1.swc
#   inflating: Aligned/Original/T_170327_8_1.swc
#   inflating: Aligned/Original/T_191007_19_1.swc
#   inflating: Aligned/Original/T_190523_5_1_M.swc
#   inflating: Aligned/Original/20170113_1013_BGUG_HuC_ltRFP_d7_F3_Neuron2.swc
#   inflating: Aligned/Original/T_160610_HuCxBG_6_1.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_7_2.swc
#   inflating: Aligned/Original/T_16119_14_3.swc
#   inflating: Aligned/Original/T_16119_5_5.swc
#   inflating: Aligned/Original/T_170119_15_1.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_1_2.swc
#   inflating: Aligned/Original/T_160708_HuCxBG_23_1.swc
#   inflating: Aligned/Original/T_170221_17_1.swc
#   inflating: Aligned/Original/T_191119_0_1.swc
#   inflating: Aligned/Original/FT_T_vmG_2.swc
#   inflating: Aligned/Original/T_191204_2_2.swc
#   inflating: Aligned/Original/20161205_1013_BGUG_HuC_ltRFP_d5_F5.swc
#   inflating: Aligned/Original/T_200108_1_GFP_3.swc
#   inflating: Aligned/Original/FT_T_maG_5.swc
#   inflating: Aligned/Original/T_160927_HuCxBG_Erk_22_1.swc
#   inflating: Aligned/Original/T_211122_12_1.swc
#   inflating: Aligned/Original/T_161010_5_2.swc
#   inflating: Aligned/Original/T_190115_12_5.swc
#   inflating: Aligned/Original/20160519_1013_BGUG_HuC_ltRFP_d6_F5.swc
#   inflating: Aligned/Original/T_150707_1_2b_full.swc
#   inflating: Aligned/Original/T_150407_12_2_full_tracing.swc
#   inflating: Aligned/Original/T_170303_15_2.swc
#   inflating: Aligned/Original/20170303_1013_BGUG_HuC_ltRFP_d7_F5.swc
#   inflating: Aligned/Original/FT_T_mdG_L2.swc
#   inflating: Aligned/Original/T_170627_15_1.swc
#   inflating: Aligned/Original/T_191212_0_1.swc
#   inflating: Aligned/Original/T_160607_15_1.swc
#   inflating: Aligned/Original/52_mod_T_161025_F1M4_prey_DS_02.swc
#   inflating: Aligned/Original/T_200120_0_5.swc
#   inflating: Aligned/Original/T_161031_0_2.swc
#   inflating: Aligned/Original/T_200916_11_1.swc
#   inflating: Aligned/Original/T_160812_5_1.swc
#   inflating: Aligned/Original/T_16119_12_2.swc
#   inflating: Aligned/Original/T_221210_16_1.swc
#   inflating: Aligned/Original/T_161121_HuCxBG_2_1.swc
#   inflating: Aligned/Original/20161006_1013_BGUG_HuC_ltRFP_d6_F5.swc
#   inflating: Aligned/Original/FT_T_mdG_T4.swc
#   inflating: Aligned/Original/T_170704_9_1.swc
#   inflating: Aligned/Original/T_190115_7_1.swc
#   inflating: Aligned/Original/T_191007_21_2.swc
#   inflating: Aligned/Original/T_190626_12_3.swc
#   inflating: Aligned/Original/T_190115_12_2.swc
#   inflating: Aligned/Original/T_190218_5_1.swc
#   inflating: Aligned/Original/T_201009_15_GFP_2.swc
#   inflating: Aligned/Original/T_180112_17_2.swc
#   inflating: Aligned/Original/T_200214_18_2.swc
#   inflating: Aligned/Original/20161206_1013_BGUG_HuC_ltRFP_d6_F4.swc
#   inflating: Aligned/Original/T_211122_2_1.swc
# ...
#   inflating: Aligned/Flipped/Left/T_200120_17_2.swc
#   inflating: Aligned/Flipped/Left/T_191119_17_1.swc
#   inflating: Aligned/Flipped/Left/T_160704_5_2.swc
#   inflating: Aligned/Flipped/Left/T_190125_8_7.swc
#   inflating: Aligned/Flipped/Left/20170805_1013_BGUG_HuC_ltRFP_d7_F4.swc
#   inflating: Aligned/Flipped/Left/T_190121_8_1.swc
#   inflating: Aligned/Flipped/Left/T_16119_13_6.swc
#   inflating: Aligned/Flipped/Left/F_L_FT_T_95_200224_F8M42.swc
#   inflating: Aligned/Flipped/Left/T_160520_1_3.swc
#   inflating: Aligned/Flipped/Left/20160922_1013_BGUG_HuC_ltRFP_d6_F4.swc
#   inflating: Aligned/Flipped/Left/T_160812_5_4.swc
#   inflating: Aligned/Flipped/Left/T_160704_1_2.swc
#   inflating: Aligned/Flipped/Left/T_160714_7_1.swc
#   inflating: Aligned/Flipped/Left/T_161031_1_1.swc
#   inflating: Aligned/Flipped/Left/T_16119_10_2.swc
#   inflating: Aligned/Flipped/Left/T_190401_0_1.swc
#   inflating: Aligned/Flipped/Left/T_16119_20_2.swc
#   inflating: Aligned/Flipped/Left/T_160812_23_4.swc
#   inflating: Aligned/Flipped/Left/T_190613_1181xBG_2_1.swc
#   inflating: Aligned/Flipped/Left/T_161026_HuCxBG_erksyp_3_3.swc
#   inflating: Aligned/Flipped/Left/20170313_1013_BGUG_HuC_ltRFP_d5_F6.swc
#   inflating: Aligned/Flipped/Left/T_190924_28_1.swc
#   inflating: Aligned/Flipped/Left/T_190702_317xBG_11_1_M.swc
#   inflating: Aligned/Flipped/Left/T_200124_3_1.swc
#   inflating: Aligned/Flipped/Left/T_161010_13_1.swc
#   inflating: Aligned/Flipped/Left/T_190125_12_5.swc
#   inflating: Aligned/Flipped/Left/FT_T_mdG_T5.swc
#   inflating: Aligned/Flipped/Left/T_180604_11_2.swc
#   inflating: Aligned/Flipped/Left/T_190121_4_1.swc
#   inflating: Aligned/Flipped/Left/T_161121_HuCxBG_7_3.swc
#   inflating: Aligned/Flipped/Left/T_161010_4_2.swc
#   inflating: Aligned/Flipped/Left/T_200710_16_1.swc
#   inflating: Aligned/Flipped/Left/T_160906_7_1.swc
#   inflating: Aligned/Flipped/Left/T_190220_1026xBG_7_1.swc
#   inflating: Aligned/Flipped/Left/20170406_1013_BGUG_HuC_ltRFP_d6_F6.swc
#   inflating: Aligned/Flipped/Left/T_190218_0_4.swc
#   inflating: Aligned/Flipped/Left/T_190702_317xBG_18_1.swc
#   inflating: Aligned/Flipped/Left/T_190718_13_4.swc
#   inflating: Aligned/Flipped/Left/20170901_1013_BGUG_HuC_ltRFP_d6_F1_Neuron2.swc
#   inflating: Aligned/Flipped/Left/T_170704_7_3.swc
#   inflating: Aligned/Flipped/Left/T_160809_19_1.swc
#   inflating: Aligned/Flipped/Left/T_160906_4_1.swc
#   inflating: Aligned/Flipped/Left/T_170303_15_1.swc
#   inflating: Aligned/Flipped/Left/T_170327_12_1.swc
#   inflating: Aligned/Flipped/Left/20161005_1013_BGUG_HuC_ltRFP_d6_F5_Neuron2.swc
#   inflating: Aligned/Flipped/Left/20170310_1013_BGUG_HuC_ltRFP_d7_F6_Neuron2.swc
#   inflating: Aligned/Flipped/Left/T_161109_8_1.swc
#   inflating: Aligned/Flipped/Left/T_190121_13_2.swc
#   inflating: Aligned/Flipped/Left/20160916_1013_BGUG_HuC_ltRFP_d7_F6.swc
#   inflating: Aligned/Flipped/Left/T_170704_10_1.swc
#   inflating: Aligned/Flipped/Left/T_191017_2_1.swc
#   inflating: Aligned/Flipped/Left/43_mod_T_160809_F2M3_liTekt_neuropil_loom+dimm+df_02.swc
#   inflating: Aligned/Flipped/Left/T_151110_5_2.swc
#   inflating: Aligned/Flipped/Left/T_170714_7_2.swc
#   inflating: Aligned/Flipped/Left/T_200124_9_1.swc
#   inflating: Aligned/Flipped/Left/T_170327_5_1.swc
#   inflating: Aligned/Flipped/Left/T_160520_12_1.swc
#   inflating: Aligned/Flipped/Left/T_161116_7_2.swc
#   inflating: Aligned/Flipped/Left/T_190711_2_1.swc
#   inflating: Aligned/Flipped/Left/T_161124_HuCxBG_23_1.swc
#   inflating: Aligned/Flipped/Left/T_190613_1181xBG_1_1.swc
#   inflating: Aligned/Flipped/Left/T_160809_11_1.swc
#   inflating: Aligned/Flipped/Left/T_160524_7_1.swc
#   inflating: Aligned/Flipped/Left/T_191011_0_1.swc
#   inflating: Aligned/Flipped/Left/20160927_1013_BGUG_HuC_ltRFP_d6_F9.swc
#   inflating: Aligned/Flipped/Left/T_211122_9_2.swc
#   inflating: Aligned/Flipped/Left/T_200818_10_GFP_1.swc
#   inflating: Aligned/Flipped/Left/T_160714_16_2.swc
#   inflating: Aligned/Flipped/Left/T_160809_3_2.swc
#   inflating: Aligned/Flipped/Left/F_L_FT_T_89_190305_F6M14.swc
#   inflating: Aligned/Flipped/Left/T_190213_10_1.swc
#   inflating: Aligned/Flipped/Left/T_200124_11_1.swc
#   inflating: Aligned/Flipped/Left/T_200903_7_GFP_1.swc
#   inflating: Aligned/Flipped/Left/T_191016_10_3.swc
#   inflating: Aligned/Flipped/Left/T_190115_24_3.swc
#   inflating: Aligned/Flipped/Left/20160916_1013_BGUG_HuC_ltRFP_d7_F14_Neuron1.swc
#   inflating: Aligned/Flipped/Left/T_16119_9_1.swc
#   inflating: Aligned/Flipped/Left/T_191007_13_2_M.swc
#   inflating: Aligned/Flipped/Left/20170506_1013_BGUG_HuC_ltRFP_d5_F8_Neuron2.swc
#   inflating: Aligned/Flipped/Left/T_190312_0_2.swc
#   inflating: Aligned/Flipped/Left/T_200909_12_1.swc
#   inflating: Aligned/Flipped/Left/T_190401_2_1.swc
#   inflating: Aligned/Flipped/Left/T_190812_2_1.swc
#   inflating: Aligned/Flipped/Left/T_190131_10_2.swc
#   inflating: Aligned/Flipped/Left/T_190125_0_5.swc
#   inflating: Aligned/Flipped/Left/T_160527_17_2.swc
#   inflating: Aligned/Flipped/Left/T_150518_1_1a_full_tracing.swc
#   inflating: Aligned/Flipped/Left/T_200916_4_2.swc
#   inflating: Aligned/Flipped/Left/20161005_1013_BGUG_HuC_ltRFP_d6_F12.swc
#   inflating: Aligned/Flipped/Left/T_160721_HuCxBG_7_1.swc
#   inflating: Aligned/Flipped/Left/T_161026_HuCxBG_erksyp_8_2.swc
#   inflating: Aligned/Flipped/Left/T_190702_317xBG_19_1_M.swc
#   inflating: Aligned/Flipped/Left/20161011_1013_BGUG_HuC_ltRFP_d5_F6_Neuron1.swc
#   inflating: Aligned/Flipped/Left/T_200120_1_1.swc
#   inflating: Aligned/Flipped/Left/T_151110_7_3.swc
#   inflating: Aligned/Flipped/Left/T_150508_fixed_55m_9_1_full_tracing.swc
#   inflating: Aligned/Flipped/Left/20161123_1013_BGUG_HuC_ltRFP_d5_F5.swc
#   inflating: Aligned/Flipped/Left/T_201102_21_GFP_1.swc
#   inflating: Aligned/Flipped/Left/T_160610_HuCxBG_1_1.swc
#   inflating: Aligned/Flipped/Left/20160623_1013_BGUG_HuC_ltRFP_d6_F4.swc
#   inflating: Aligned/Flipped/Left/T_170714_10_1.swc
#   inflating: Aligned/Flipped/Left/T_161121_7_1.swc
#   inflating: Aligned/Flipped/Left/T_191007_8_3.swc
#   inflating: Aligned/Flipped/Left/T_180102_6_3.swc
#   inflating: Aligned/Flipped/Left/T_160714_2_2.swc
#   inflating: Aligned/Flipped/Left/T_150304_1_3.swc
#   inflating: Aligned/Flipped/Left/20160913_1013_BGUG_HuC_ltRFP_d7_F1.swc
#   inflating: Aligned/Flipped/Left/T_161116_24_2.swc
#   inflating: Aligned/Flipped/Left/T_200818_17_4.swc
#   inflating: Aligned/Flipped/Left/T_200120_10_2.swc
#   inflating: Aligned/Flipped/Left/T_190426_1181xBG_10_1.swc
#   inflating: Aligned/Flipped/Left/T_200912_15_GFP_1.swc
#   inflating: Aligned/Flipped/Left/T_180219_6_1.swc
#   inflating: Aligned/Flipped/Left/T_161026_HuCxBG_erksyp_2_5.swc
#   inflating: Aligned/Flipped/Left/T_190924_32_2.swc
#   inflating: Aligned/Flipped/Left/T_18116_1_3.swc
#   inflating: Aligned/Flipped/Left/20160929_1013_BGUG_HuC_ltRFP_d6_F8_Neuron2.swc
#   inflating: Aligned/Flipped/Left/T_170210_4_1.swc
#   inflating: Aligned/Flipped/Left/T_161019_13_2.swc
#   inflating: Aligned/Flipped/Left/T_190206_19_1.swc
#   inflating: Aligned/Flipped/Left/T_161005_HuCxBG_erk_15_4.swc
#   inflating: Aligned/Flipped/Left/T_170821_14_2.swc
#   inflating: Aligned/Flipped/Left/T_190812_14_2_M.swc
#   inflating: Aligned/Flipped/Left/T_181008_16_2_Eva.swc
#   inflating: Aligned/Flipped/Left/T_191016_5_2.swc
#   inflating: Aligned/Flipped/Left/T_150609_354_fixed_10_1_full_tracing.swc
#   inflating: Aligned/Flipped/Left/T_191204_0_4.swc
#   inflating: Aligned/Flipped/Left/20170609_1013_BGUG_HuC_ltRFP_d7_F3_Neuron2.swc
#   inflating: Aligned/Flipped/Left/T_151208_17_2.swc
#   inflating: Aligned/Flipped/Left/T_190812_6_2.swc
#   inflating: Aligned/Flipped/Left/T_170529_19_1.swc
#   inflating: Aligned/Flipped/Left/F_L_FT_T_109_200226_F3M8.swc
#   inflating: Aligned/Flipped/Left/FT_T_lG_6.swc
#   inflating: Aligned/Flipped/Left/T_201102_4_GFP_2.swc
#   inflating: Aligned/Flipped/Left/T_190523_6_1.swc
#   inflating: Aligned/Flipped/Left/T_200728_2_GFP_2.swc
#   inflating: Aligned/Flipped/Left/F_L_FT_T_101_200225_F3M14.swc
#   inflating: Aligned/Flipped/Left/T_170704_19_4.swc
#   inflating: Aligned/Flipped/Left/T_160708_HuCxBG_4_1.swc
#   inflating: Aligned/Flipped/Left/T_160708_HuCxBG_17_1.swc
#   inflating: Aligned/Flipped/Left/T_160927_HuCxBG_Erk_16_2.swc
#   inflating: Aligned/Flipped/Left/T_190218_12_1.swc
#   inflating: Aligned/Flipped/Left/T_170119_11_1.swc
#   inflating: Aligned/Flipped/Left/20160720_1013_BGUG_HuC_ltRFP_d6_F8_Neuron1.swc
#   inflating: Aligned/Flipped/Left/T_150407_7_1_full_tracing.swc
#   inflating: Aligned/Flipped/Left/68_mod_T_160808_F5M5_prey_02.swc
#   inflating: Aligned/Flipped/Left/T_160510_Image7_Stitch_2.swc
#   inflating: Aligned/Flipped/Left/T_191119_7_1.swc
#   inflating: Aligned/Flipped/Left/T_161109_15_1.swc
#   inflating: Aligned/Flipped/Left/T_200909_15_GFP_2.swc
#   inflating: Aligned/Flipped/Left/T_170627_10_3.swc
#   inflating: Aligned/Flipped/Left/T_190131_7_1.swc
#   inflating: Aligned/Flipped/Left/T_190426_1181xBG_6_1_MK.swc
#   inflating: Aligned/Flipped/Left/T_170627_2_2.swc
#   inflating: Aligned/Flipped/Left/T_160610_HuCxBG_16_1.swc
#   inflating: Aligned/Flipped/Left/T_190719_4_1.swc
#   inflating: Aligned/Flipped/Left/T_151130_2_2.swc
#   inflating: Aligned/Flipped/Left/T_190218_10_1.swc
#   inflating: Aligned/Flipped/Left/T_160406_5b_1.swc
#   inflating: Aligned/Flipped/Left/T_200818_8_GFP_1.swc
#   inflating: Aligned/Flipped/Left/T_190523_5_1_M.swc
#   inflating: Aligned/Flipped/Left/20170113_1013_BGUG_HuC_ltRFP_d7_F3_Neuron2.swc
#   inflating: Aligned/Flipped/Left/T_16119_14_3.swc
#   inflating: Aligned/Flipped/Left/T_16119_5_5.swc
#   inflating: Aligned/Flipped/Left/T_170119_15_1.swc
#   inflating: Aligned/Flipped/Left/T_160927_HuCxBG_Erk_1_2.swc
#   inflating: Aligned/Flipped/Left/T_160708_HuCxBG_23_1.swc
#   inflating: Aligned/Flipped/Left/FT_T_vmG_2.swc
#   inflating: Aligned/Flipped/Left/T_191204_2_2.swc
#   inflating: Aligned/Flipped/Left/20161205_1013_BGUG_HuC_ltRFP_d5_F5.swc
#   inflating: Aligned/Flipped/Left/FT_T_maG_5.swc
#   inflating: Aligned/Flipped/Left/T_190115_12_5.swc
#   inflating: Aligned/Flipped/Left/20160519_1013_BGUG_HuC_ltRFP_d6_F5.swc
#   inflating: Aligned/Flipped/Left/T_150707_1_2b_full.swc
#   inflating: Aligned/Flipped/Left/T_150407_12_2_full_tracing.swc
#   inflating: Aligned/Flipped/Left/20170303_1013_BGUG_HuC_ltRFP_d7_F5.swc
#   inflating: Aligned/Flipped/Left/FT_T_mdG_L2.swc
#   inflating: Aligned/Flipped/Left/T_191212_0_1.swc
#   inflating: Aligned/Flipped/Left/52_mod_T_161025_F1M4_prey_DS_02.swc
#   inflating: Aligned/Flipped/Left/T_200120_0_5.swc
#   inflating: Aligned/Flipped/Left/T_161031_0_2.swc
#   inflating: Aligned/Flipped/Left/T_160812_5_1.swc
#   inflating: Aligned/Flipped/Left/20161006_1013_BGUG_HuC_ltRFP_d6_F5.swc
#   inflating: Aligned/Flipped/Left/T_191007_21_2.swc
#   inflating: Aligned/Flipped/Left/T_190626_12_3.swc
#   inflating: Aligned/Flipped/Left/T_201009_15_GFP_2.swc
#   inflating: Aligned/Flipped/Left/T_180112_17_2.swc
#   inflating: Aligned/Flipped/Left/T_200214_18_2.swc
#   inflating: Aligned/Flipped/Left/20161206_1013_BGUG_HuC_ltRFP_d6_F4.swc
#   inflating: Aligned/Flipped/Left/20161013_1013_BGUG_HuC_ltRFP_d7_F4.swc
#   inflating: Aligned/Flipped/Left/T_190531_11_5.swc
#   inflating: Aligned/Flipped/Left/T_160502_8_2.swc
#   inflating: Aligned/Flipped/Left/T_160913_HuCxBG_1_2.swc
#   inflating: Aligned/Flipped/Left/20170722_1013_BGUG_HuC_ltRFP_d7_F3.swc
#   inflating: Aligned/Flipped/Left/20160920_1013_BGUG_HuC_ltRFP_d6_F9.swc
#   inflating: Aligned/Flipped/Left/66_mod_T_160727_F5M6_loom+dimm_02.swc
#   inflating: Aligned/Flipped/Left/T_191008_10_1.swc
#   inflating: Aligned/Flipped/Left/T_170601_14_2.swc
#   inflating: Aligned/Flipped/Left/T_190405_23_1.swc
#   inflating: Aligned/Flipped/Left/20160916_1013_BGUG_HuC_ltRFP_d7_F2.swc
#   inflating: Aligned/Flipped/Left/20161212_1013_BGUG_HuC_ltRFP_d5_F1_Neuron2.swc
#   inflating: Aligned/Flipped/Left/T_160714_13_1.swc
#   inflating: Aligned/Flipped/Left/T_160527_10_1.swc
#   inflating: Aligned/Flipped/Left/T_161124_HuCxBG_22_1.swc
#   inflating: Aligned/Flipped/Left/T_200120_7_4.swc
#   inflating: Aligned/Flipped/Left/T_201027_7_GFP_1.swc
#   inflating: Aligned/Flipped/Left/T_160510_Image7_Stitch_1.swc
#   inflating: Aligned/Flipped/Left/T_190909_12_3.swc
#   inflating: Aligned/Flipped/Left/20170113_1013_BGUG_HuC_ltRFP_d7_F4.swc
#   inflating: Aligned/Flipped/Left/T_161124_HuCxBG_2_2.swc
#   inflating: Aligned/Flipped/Left/T_170704_19_1.swc
#   inflating: Aligned/Flipped/Left/T_161116_7_3.swc
#   inflating: Aligned/Flipped/Left/27_mod_T_160726_F2M3_Loom+Dimm_02.swc
#   inflating: Aligned/Flipped/Left/T_191008_4_1.swc
#   inflating: Aligned/Flipped/Left/T_200818_9_GFP_4.swc
#   inflating: Aligned/Flipped/Left/T_150707_14_c_full.swc
#   inflating: Aligned/Flipped/Left/T_160905_0_3.swc
#   inflating: Aligned/Flipped/Left/T_180102_15_1.swc
#   inflating: Aligned/Flipped/Left/T_190121_9_4.swc
#   inflating: Aligned/Flipped/Left/T_160906_9_1.swc
#   inflating: Aligned/Flipped/Left/T_181108_6_1.swc
#   inflating: Aligned/Flipped/Left/T_150707_3_1b_full.swc
#   inflating: Aligned/Flipped/Left/T_190918_6_1.swc
#   inflating: Aligned/Flipped/Left/T_190918_25_1_M.swc
#   inflating: Aligned/Flipped/Left/T_190221_20_2.swc
#   inflating: Aligned/Flipped/Left/T_190121_8_2.swc
#   inflating: Aligned/Flipped/Left/T_170601_18_5.swc
#   inflating: Aligned/Flipped/Left/24_mod_T_160725_F1M5_prey_02.swc
#   inflating: Aligned/Flipped/Left/20160920_1013_BGUG_HuC_ltRFP_d6_F11.swc
#   inflating: Aligned/Flipped/Left/T_150827_7_1.swc
#   inflating: Aligned/Flipped/Left/T_190718_2_2.swc
#   inflating: Aligned/Flipped/Left/T_160812_7_2.swc
#   inflating: Aligned/Flipped/Left/T_151130_3_1.swc
#   inflating: Aligned/Flipped/Left/T_161010_15_2.swc
#   inflating: Aligned/Flipped/Left/T_190812_20_1.swc
#   inflating: Aligned/Flipped/Left/T_190401_7_4.swc
#   inflating: Aligned/Flipped/Left/T_201027_11_GFP_3.swc
#   inflating: Aligned/Flipped/Left/T_190531_6_2_M.swc
#   inflating: Aligned/Flipped/Left/T_150707_8_3_full.swc
#   inflating: Aligned/Flipped/Left/T_151110_4_2.swc
#   inflating: Aligned/Flipped/Left/20170117_1013_BGUG_HuC_ltRFP_d5_F4.swc
#   inflating: Aligned/Flipped/Left/T_180102_5_1.swc
#   inflating: Aligned/Flipped/Left/20160726_1013_BGUG_HuC_ltRFP_d6_F2.swc
#   inflating: Aligned/Flipped/Left/20161004_1013_BGUG_HuC_ltRFP_d5_F5.swc
#   inflating: Aligned/Flipped/Left/T_16119_8_1.swc
#   inflating: Aligned/Flipped/Left/20161011_1013_BGUG_HuC_ltRFP_d5_F6_Neuron3.swc
#   inflating: Aligned/Flipped/Left/T_161019_4_4.swc
#   inflating: Aligned/Flipped/Left/T_160809_18_3.swc
#   inflating: Aligned/Flipped/Left/T_191128_14_1.swc
#   inflating: Aligned/Flipped/Left/20161014_1013_BGUG_HuC_ltRFP_d7_F4.swc
#   inflating: Aligned/Flipped/Left/T_180111_4_2.swc
#   inflating: Aligned/Flipped/Left/T_170201_13_1.swc
#   inflating: Aligned/Flipped/Left/T_190125_0_4.swc
#   inflating: Aligned/Flipped/Left/T_161019_12_2.swc
#   inflating: Aligned/Flipped/Left/20161014_1013_BGUG_HuC_ltRFP_d7_F5.swc
#   inflating: Aligned/Flipped/Left/T_150707_8_1_full.swc
#   inflating: Aligned/Flipped/Left/T_161108_0_1.swc
#   inflating: Aligned/Flipped/Left/T_150714_5_3a_full_tracing.swc
#   inflating: Aligned/Flipped/Left/T_160705_16_4.swc
#   inflating: Aligned/Flipped/Left/20170310_1013_BGUG_HuC_ltRFP_d7_F5.swc
#   inflating: Aligned/Flipped/Left/T_161124_HuCxBG_22_2.swc
#   inflating: Aligned/Flipped/Left/T_170601_20_3.swc
#   inflating: Aligned/Flipped/Left/20160916_1013_BGUG_HuC_ltRFP_d7_F9.swc
#   inflating: Aligned/Flipped/Left/T_200710_10_2.swc
#   inflating: Aligned/Flipped/Left/T_161031_3_3.swc
#   inflating: Aligned/Flipped/Left/T_190527_1181xBG_0_1_M.swc
#   inflating: Aligned/Flipped/Left/T_160812_9_1.swc
#   inflating: Aligned/Flipped/Left/T_160905_7_2.swc
#   inflating: Aligned/Flipped/Left/T_181108_11_2_Eva.swc

# %% [markdown]
# Next we need to understand the data and tools we'll be working with:
# * **Data**: Each neuron's morphology is stored as an .SWC file. Try opening one in a text editor, and then understanding the format using this [guide](http://www.neuronland.org/NLMorphologyConverter/MorphologyFormats/SWC/Spec.html).
# * **Tools**: We're going to use a library called [neurom](https://neurom.readthedocs.io/en/stable/quickstart.html) to load these .SWC files.
#
# Now we'll make a list of the neurons which we can successfully load with neurom.
#
# If this or later parts of the notebook run too slowly (more than a few minutes for a single cell) try working with a subset of the data by sampling from this list.

# %%
# Filtering
neuron_paths = []
for file in os.listdir(folder_path):
    neuron_path = folder_path + '/' + file

    try:
        m = nm.load_morphology(neuron_path) # try to load the morphology
        neuron_paths.append(neuron_path) # if this works appened the path to neuron_paths
    except:
        pass # otherwise just skip this neuron

print("Loaded " + str(len(neuron_paths)) + " of " + str(len(os.listdir(folder_path))) + " neurons.")
# Out:
# Loaded 3175 of 4327 neurons.

# %% [markdown]
# ### Part 1 - Looking at the data
#
# Now we can load the morphologies, let's try plotting some neurons in 2d. For random neurons, the code below plots:
# * It's morphology as a black line.
# * It's points as grey circles.
# * The location of it's soma as a green circle.
#
# Note how we access these properties from the loaded morphology.
#
# When working with real data, especially large datasets, it's important to get a "feel" for the data, so try looking at as many neurons as possible - how similar are they?

# %%
# Plotting single neurons in 2d
n = np.random.randint(low=0, high=len(neuron_paths)) # sample a random neuron
m = nm.load_morphology(neuron_paths[n]) # load it's morphology

fig, ax = figure()
plot_morph(m,ax=ax, soma_outline=0, plane='xy', diameter_scale=None, linewidth=3, color='k', alpha=1.0)
plt.scatter(m.points[:,0], m.points[:,1], color='xkcd:grey')
plt.scatter(m.soma.center[0], m.soma.center[1], s=90, color='g')

# %% [markdown]
# Now try writing some code to plot single neurons in 3d.

# %%
# Plotting single neurons in 3d
from mpl_toolkits.mplot3d import Axes3D  # 仅为触发3D后端
n = np.random.randint(0, len(neuron_paths))
m = nm.load_morphology(neuron_paths[n])

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(m.points[:,0], m.points[:,1], m.points[:,2], s=1, alpha=0.6)
ax.scatter([m.soma.center[0]],[m.soma.center[1]],[m.soma.center[2]], s=40)
ax.set_box_aspect([1,1,1])
ax.set_axis_off()
plt.show()

#fig = plt.figure()

# %% [markdown]
# Now try to plot all of the neurons together on a single axis in either 2 or 3d.
#
# In general using a low alpha (transparency) value can be helpful for plots with many points.
#
# [Figure 1E](https://doi.org/10.1016/j.neuron.2019.04.034) could provide you with some inspiration for what this plot could look like!

# %%
# Plot all of the neurons together
#fig, ax = figure()
fig, ax = figure()
for p in neuron_paths:
    m = nm.load_morphology(p)
    plot_morph(m, ax=ax, soma_outline=0, plane='xy',
               diameter_scale=None, linewidth=0.5, alpha=0.08)
plt.show()

# %% [markdown]
# ### Part 2 - Estimating a connectivity matrix
#
# In week 3 of the course we learnt about [connectomes](https://youtu.be/LANmSbhbdBA?si=HKDoBD7IbS3o4Uhv) - diagrams describing how every neuron connects to every other neuron in an animal.
#
# To create a connectome we need higher resolution data (from electron microscopy), but from the data we have we can estimate how strongly *areas* of the brain connect to each other.
#
# Ideally we would do this by determining where each neuron's dendrites and axon were, dividing the brain into anatomical regions (optic tectum, cerebellum etc), and then working out where the dendrites in each region receive their inputs from.
#
# Though, as a *very rough estimate* we can:
# 1. Treat each neuron as having a single input and output point; respectively it's soma and the furthest point from it's soma.
# 2. Divide the brain into a 3d grid.
# 3. Assign each neuron's input and output point to a pair of grid cells (which we'll term voxels).
#
# Let's work through each of these three steps.

# %% [markdown]
# #### Part 2.1
# Write code to define the output point for a single neuron. Check that it works by plotting some single neurons in either 2 or 3d and marking their output point with a coloured circle.

# %%
# Define the output point for a single neuron
n = np.random.randint(low=0, high=len(neuron_paths))
m = nm.load_morphology(neuron_paths[n])

# Check that this seems to work by plotting some data
fig, ax = figure()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3611303398.py in <cell line: 0>()
#       9
#      10 # 取该神经元的输出点（每个axon的末端）
# ---> 11 output_pts = np.array([sec.points[-1] for sec in m.axon.iter()])
#      12
#      13 # 在图上标出输出点（红色圆点）
#
# AttributeError: 'Morphology' object has no attribute 'axon'

# %% [markdown]
# Now load each neuron in turn and extract it's input (soma) and output (furthest point from soma) locations.
#
# Real datasets can contain small errors, and here you may find that some neuron's lack any points.
#
# In that case skip over those neurons as in Part 0, though make sure that you end up with an equal number of inputs and outputs by using an [assert statement](https://www.w3schools.com/python/ref_keyword_assert.asp) at the end of your code.

# %%
# Define each neurons input and output point
inputs, outputs = [], []

# Use an assert statement at the end of your code

# %% [markdown]
# Now try plotting all of the neurons (on one axis) as single lines connecting their input and output points.
#
# If you've done this correctly it should resemble the last figure in Part 1 surprisingly well.

# %%
# Plot all of the neurons together in line form (input-output point)
fig, ax = figure()

# %% [markdown]
# #### Part 2.2
#
# Now we need to divide the brain into a 3d grid.
#
# Too coarse a grid may be uninformative, but too fine a grid may be overly sparse.
#
# Try to check if your grid seems reasonable by overlaying it on some whole-brain plots.

# %%
# Divide the brain into a 3d grid

# Try to check if your grid seems reasonable (with some plots)

# %% [markdown]
# #### Part 2.3
#
# Finally we need to assign each neuron's input and output point to a pair of voxels.
#
# Create a voxel (input) x voxel (output) connectivity matrix where each cell reports the number of neuron's which connect that pair.
#
# Try to visualise this matrix as a heatmap.

# %%
# Create a connectivity matrix

# Visualise this matrix as a heatmap

# %% [markdown]
# ### Part 3 - Open exploration
#
# Now that you know how to work with this data, you should try to explore something that interests you!
#
# Here are a few ideas to get you started:
# * **Improving our approach** - as we highlighted above, our connectivity matrix is at best a very rough estimate as we reduce neurons to lines and brain regions to cells in an arbitrary grid. How could you improve on this? The original [paper](https://doi.org/10.1016/j.neuron.2019.04.034) may provide some ideas.
# * **Bilateral symmetry** - in biology many structures are symmetrical across the midline. How similar are the left and right sides of the larval zebrafish brain? Are there any areas which are asymmetrical in their connectivity?
# * **Information flow** - this [paper](https://www.science.org/doi/10.1126/science.add9330#sec-4) uses a signal cascade algorithm to estimate how information flows through the *Drosophila* larva connectome. Try implementing their approach and see if you can discover any patterns in how signals flow through the larval zebrafish brain.
